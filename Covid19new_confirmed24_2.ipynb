# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

conf_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv',error_bad_lines=False)
deaths_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Deaths.csv', error_bad_lines=False)
recv_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Recovered.csv',error_bad_lines=False)

conf_df =conf_df.set_index('Country/Region')
deaths_df = deaths_df.set_index('Country/Region')
recv_df = recv_df.set_index('Country/Region')

conf_df.drop(index='Mainland China', inplace=True)
deaths_df.drop(index='Mainland China', inplace=True)
recv_df.drop(index='Mainland China', inplace=True)

#Για Ευρώπη μόνο ενεργοποιήστε τα παρακάτω

# %%
conf=conf_df.sum()
deaths= deaths_df.sum()
recv= recv_df.sum()

conf = conf.drop(labels=['Lat', 'Long'])
deaths = deaths.drop(labels=['Lat', 'Long'])
recv = recv.drop(labels=['Lat', 'Long'])

C=[]
C.append(conf[0])
for i in range(len(conf)-1):
    dif = conf[i+1] - conf[i]
    C.append(dif)
D=[]
D.append(deaths[0])
for i in range(len(deaths)-1):
    dif = deaths[i+1] - deaths[i]
    D.append(dif)
R=[]
R.append(recv[0])
for i in range(len(recv)-1):
    dif = recv[i+1] - recv[i]
    R.append(dif)
    

dfsum = pd.DataFrame(
    {'Επιβεβαιωμένα κρούσματα': C,
     'Έχουν αναρρώσει': D,
     'Νεκροί': R
    })

# %%
L = conf.index

# %%
dfsum.set_index(L)
# Out:
#          Επιβεβαιωμένα κρούσματα  Έχουν αναρρώσει  Νεκροί
# 1/22/20                      8.0              0.0     0.0
# 1/23/20                      6.0              0.0     0.0
# 1/24/20                     11.0              0.0     0.0
# 1/25/20                     10.0              0.0     0.0
# 1/26/20                     21.0              0.0     3.0
# 1/27/20                      8.0              0.0     0.0
# 1/28/20                     20.0              0.0     3.0
# 1/29/20                     12.0              0.0     0.0
# 1/30/20                     14.0              0.0     2.0
# 1/31/20                     34.0              0.0     0.0
# 2/1/20                      23.0              0.0     1.0
# 2/2/20                      13.0              1.0     0.0
# 2/3/20                       8.0              0.0     0.0
# 2/4/20                      24.0              1.0     0.0
# 2/5/20                      15.0              0.0     0.0
# ...

# %%
dfsum.plot(kind='area', 
             alpha=0.25, # 0-1, default value a= 0.5
             stacked=False,
             figsize=(18, 9),
            )

plt.title(' Πλήθος νέων κρουσμάτων Covid-19 εκτός Κίνας')
plt.ylabel('Πληθος ατόμων')
plt.xlabel('Ημέρες')

plt.show()

# %%
dftotal = pd.DataFrame({ 'Κρούσματα': conf, 'Νεκροί': deaths, 'Έχουν αναρρώσει:': recv } )

# %%
dftotal = dftotal.tail(15)

# %%
dftotal.plot(kind='area', 
             alpha=0.25, # 0-1, default value a= 0.5
             stacked=False,
             figsize=(18, 9),
            )

plt.title(' Κρούσματα Covid-19 εκτός Κίνας')
plt.ylabel('Πληθος ατόμων')
#plt.xlabel('Ημέρες')

plt.show()

# %%
conf_it = conf_df.loc['Italy']
deaths_it = deaths_df.loc['Italy']
recv_it = recv_df.loc['Italy']

# %%
dfitaly = pd.DataFrame({ 'Κρούσματα': conf_it, 'Νεκροί': deaths_it, 'Έχουν αναρρώσει:': recv_it } )

# %%
dfitaly = dfitaly.tail(15)

# %%
dfitaly
# Out:
#         Κρούσματα Νεκροί Έχουν αναρρώσει:
# 2/10/20         3      0                0
# 2/11/20         3      0                0
# 2/12/20         3      0                0
# 2/13/20         3      0                0
# 2/14/20         3      0                0
# 2/15/20         3      0                0
# 2/16/20         3      0                0
# 2/17/20         3      0                0
# 2/18/20         3      0                0
# 2/19/20         3      0                0
# 2/20/20         3      0                0
# 2/21/20        20      1                0
# 2/22/20        62      2                1
# 2/23/20       155      3                2
# 2/24/20       229      7                1

# %%
dfitaly.plot(kind='area', 
             alpha=0.25, # 0-1, default value a= 0.5
             stacked=False,
             figsize=(18, 9),
            )

plt.title(' Κρούσματα Covid-19 στην Ιταλία')
plt.ylabel('Πληθος ατόμων')
#plt.xlabel('Ημέρες')

plt.show()
